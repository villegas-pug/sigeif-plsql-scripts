# %% [markdown]
# ## `░ 1. Instalación de librerias`

# %%
# %pip install graphviz
# %pip install ipython

# %% [markdown]
# #### `» 1.1 Importar librerias`

# %%
import pandas as pd
from graphviz import Digraph

# %% [markdown]
# #### `» 1.2 Variables globales y configuración`

# %%
BASE_PATH = './data/diagramas'

# %% [markdown]
# ## `░ 2. Generar diagrama de Despliegue`

# %%
from graphviz import Digraph
from IPython.display import display, Image

# Crear el objeto Digraph
dot = Digraph(
    comment='Diagrama de Despliegue - Base de Datos SSI',
    format='png',
    graph_attr={
        'rankdir': 'LR',
        'bgcolor': 'transparent',
        'fontname': 'Arial',
        'fontsize': '10',
    },
    node_attr={
        'shape': 'box',
        'style': 'filled,rounded',
        'fillcolor': '#f9f9f9',
        'color': '#555555',
        'fontname': 'Arial',
        'fontsize': '10',
    },
    edge_attr={
        'color': '#777777',
        'arrowsize': '0.7',
        'fontname': 'Arial',
        'fontsize': '8',
    }
)

# Definir las tablas y sus relaciones
tables = {
    "SSI_SERVICIOS_INABIF": [],
    "SSI_PROFESION": [],
    "SSI_GRUPO_SOCIAL": [],
    "SSI_ZONA_INTERVENCION": ["SSI_SERVICIOS_INABIF"],
    "SSI_EQUIPO_TRABAJO": ["SSI_ZONA_INTERVENCION", "SSI_PROFESION"],
    "SSI_ALIADOS": ["SSI_ZONA_INTERVENCION", "SSI_GRUPO_SOCIAL"],
    "SSI_CONTACTO": ["SSI_ALIADOS"],
    "SSI_POTENCIALES_FAMILIAS": ["SSI_ZONA_INTERVENCION", "SSI_ALIADOS", "SSI_SERVICIOS_INABIF"],
    "SSI_MOTIVO_REFERENCIA": [],
    "SSI_FAMILIA_MOTIVO_REFERENCIA": ["SSI_POTENCIALES_FAMILIAS", "SSI_MOTIVO_REFERENCIA"],
    "SSI_FAMILIA_INTEGRANTES": ["SSI_POTENCIALES_FAMILIAS"],
    "SSI_ANEXOS_PREGUNTAS": ["SSI_SERVICIOS_INABIF"],
    "SSI_ANEXOS_RESPUESTAS": ["SSI_ANEXOS_PREGUNTAS", "SSI_POTENCIALES_FAMILIAS", "SSI_FAMILIA_INTEGRANTES"],
    "SSI_UBIGEO_NOMBRES": [],
    "SSI_OBJETIVOS_ESPECIFICOS": ["SSI_SERVICIOS_INABIF"],
    "SSI_MODULOS": ["SSI_OBJETIVOS_ESPECIFICOS"],
    "SSI_UNIDADES": ["SSI_MODULOS"],
    "SSI_TEMAS": ["SSI_UNIDADES"],
    "SSI_UNIDAD_SESIONES": ["SSI_UNIDADES", "SSI_OBJETIVOS_ESPECIFICOS"],
    "SSI_TALLERES": ["SSI_OBJETIVOS_ESPECIFICOS", "SSI_UNIDAD_SESIONES", "SSI_TEMAS"],
    "SSI_PATFAM": ["SSI_POTENCIALES_FAMILIAS"],
    "SSI_DET_PATFAM": ["SSI_PATFAM", "SSI_OBJETIVOS_ESPECIFICOS", "SSI_MODULOS", "SSI_UNIDADES", "SSI_TEMAS", "SSI_UNIDAD_SESIONES", "SSI_TALLERES"],
    "SSI_EJECUCION_SESIONES": ["SSI_DET_PATFAM", "SSI_UNIDAD_SESIONES"],
    "SSI_EJEC_SESION_INTEGRANTES": ["SSI_EJECUCION_SESIONES", "SSI_FAMILIA_INTEGRANTES"],
    "SSI_PROG_TALLERES": ["SSI_TALLERES"],
    "SSI_PROG_TALLER_FAMILIAS": ["SSI_PROG_TALLERES", "SSI_DET_PATFAM", "SSI_POTENCIALES_FAMILIAS"],
    "SSI_ANEXO_FASES": ["SSI_SERVICIOS_INABIF"],
    "SSI_ACTAS": ["SSI_ALIADOS"],
    "SSI_CODIGOS_FAMILIAS": ["SSI_SERVICIOS_INABIF", "SSI_POTENCIALES_FAMILIAS", "SSI_FAMILIA_INTEGRANTES"]
}

# Colores para las tablas principales
table_colors = {
    "SSI_SERVICIOS_INABIF": "#FFD700",  # Dorado
    "SSI_PROFESION": "#87CEFA",        # Azul claro
    "SSI_GRUPO_SOCIAL": "#98FB98",     # Verde claro
    "SSI_MOTIVO_REFERENCIA": "#DDA0DD", # Ciruela
    "SSI_UBIGEO_NOMBRES": "#FFA07A"    # Salmón claro
}

# Añadir nodos
for table, dependencies in tables.items():
    fill_color = table_colors.get(table, "#f9f9f9")
    dot.node(table, table, style='filled,rounded', fillcolor=fill_color)

# Añadir relaciones
for table, dependencies in tables.items():
    for dep in dependencies:
        dot.edge(dep, table)

# Renderizar y mostrar el diagrama
dot.render(f'{BASE_PATH}/diagrama_despliegue_ssi', format='png', cleanup=True)
display(Image(filename=f'{BASE_PATH}/diagrama_despliegue_ssi.png'))

# %% [markdown]
# ## `░ 3. Generar diagrama de Componentes`

# %% [markdown]
# #### `» 3.1 Familias Igualitarias`

# %%
from graphviz import Digraph
from IPython.display import display, Image

# Crear el objeto Digraph
dot = Digraph(
    comment='Diagrama de Componentes - Sistema Integral de Familias Igualitarias',
    format='png',
    graph_attr={
        'rankdir': 'TB',
        'bgcolor': 'transparent',
        'fontname': 'Arial',
        'fontsize': '12',
    },
    node_attr={
        'shape': 'component',
        'style': 'filled,rounded',
        'fillcolor': '#f9f9f9',
        'color': '#555555',
        'fontname': 'Arial',
        'fontsize': '10',
    },
    edge_attr={
        'color': '#777777',
        'arrowsize': '0.7',
        'fontname': 'Arial',
        'fontsize': '8',
    }
)

# Añadir el contenedor principal
with dot.subgraph(name='cluster_main_system') as c:
    c.attr(label='Sistema Integral de Familias Igualitarias', style='filled', color='lightgrey', fontsize='14', fontname='Arial Bold')

    # Añadir componentes con sus puertos
    c.node('Gestión de Servicios', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFD700"><b>Gestión de Servicios</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Servicio</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Servicio</td></tr>\n'
           '</table>>')

    c.node('Gestión de Profesiones', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#87CEFA"><b>Gestión de Profesiones</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Profesión</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Profesión</td></tr>\n'
           '</table>>')

    c.node('Gestión de Grupos Sociales', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#98FB98"><b>Gestión de Grupos Sociales</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Grupo Social</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Grupo Social</td></tr>\n'
           '</table>>')

    c.node('Gestión de Zonas de Intervención', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFA07A"><b>Gestión de Zonas de Intervención</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Zona</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Zona</td></tr>\n'
           '</table>>')

    c.node('Gestión de Equipos de Trabajo', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#DDA0DD"><b>Gestión de Equipos de Trabajo</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Equipo</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Equipo</td></tr>\n'
           '</table>>')

    c.node('Gestión de Aliados', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#E6E6FA"><b>Gestión de Aliados</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Aliado</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Aliado</td></tr>\n'
           '</table>>')

    c.node('Gestión de Familias', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFB6C1"><b>Gestión de Familias</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Familia</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Familia</td></tr>\n'
           '</table>>')

    c.node('Gestión de Motivos de Referencia', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#F0E68C"><b>Gestión de Motivos de Referencia</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Motivo</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Motivo</td></tr>\n'
           '</table>>')

    c.node('Gestión de Anexo y Respuestas', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#E0FFFF"><b>Gestión de Anexo y Respuestas</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Anexo</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Anexo</td></tr>\n'
           '</table>>')

    c.node('Gestión de Ubigeo', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#90EE90"><b>Gestión de Ubigeo</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Ubicación</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Ubicación</td></tr>\n'
           '</table>>')

    c.node('Gestión de Talleres y Sesiones', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFE4B5"><b>Gestión de Talleres y Sesiones</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Programar Taller</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Registrar Sesión</td></tr>\n'
           '</table>>')

    c.node('Gestión de PATFAM', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFDEAD"><b>Gestión de PATFAM</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar PATFAM</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar PATFAM</td></tr>\n'
           '</table>>')

    c.node('Gestión de Ejecución de Sesiones', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#D8BFD8"><b>Gestión de Ejecución de Sesiones</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Ejecutar Sesión</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Registrar Asistencia</td></tr>\n'
           '</table>>')

    c.node('Gestión de Actas', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFDAB9"><b>Gestión de Actas</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Acta</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Acta</td></tr>\n'
           '</table>>')

    c.node('Gestión de Códigos de Familias', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#EEE8AA"><b>Gestión de Códigos de Familias</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Código</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Código</td></tr>\n'
           '</table>>')

    c.node('Gestión de Fases de Anexo', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#F5DEB3"><b>Gestión de Fases de Anexo</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Fase</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Fase</td></tr>\n'
           '</table>>')

# Añadir actor
dot.node('Responsable', '<<table border="0" cellborder="0">\n'
         '   <tr><td><font point-size="10">\u263A Responsable de Intervención Profesional</font></td></tr>\n'
         '</table>>', shape='plaintext')

# Añadir conexiones entre componentes
dot.edge('Responsable:e', 'Gestión de Servicios:p1:w', label='Ingresar Servicios', labelfontsize='8.0')
dot.edge('Responsable:e', 'Gestión de Talleres y Sesiones:p1:w', label='Programar Taller', labelfontsize='8.0')
dot.edge('Responsable:e', 'Gestión de PATFAM:p1:w', label='Registrar PATFAM', labelfontsize='8.0')

dot.edge('Gestión de Servicios:p2:e', 'Gestión de Zonas de Intervención:p1:w', label='Registrar Zona', labelfontsize='8.0')
dot.edge('Gestión de Zonas de Intervención:p2:e', 'Gestión de Equipos de Trabajo:p1:w', label='Registrar Equipo', labelfontsize='8.0')
dot.edge('Gestión de Zonas de Intervención:p2:e', 'Gestión de Aliados:p1:w', label='Registrar Aliado', labelfontsize='8.0')
dot.edge('Gestión de Aliados:p2:e', 'Gestión de Familias:p1:w', label='Registrar Familia', labelfontsize='8.0')
dot.edge('Gestión de Familias:p2:e', 'Gestión de Motivos de Referencia:p1:w', label='Registrar Motivo', labelfontsize='8.0')
dot.edge('Gestión de Talleres y Sesiones:p2:e', 'Gestión de Ejecución de Sesiones:p1:w', label='Ejecutar Sesión', labelfontsize='8.0')
dot.edge('Gestión de Ejecución de Sesiones:p2:e', 'Gestión de Actas:p1:w', label='Registrar Acta', labelfontsize='8.0')
dot.edge('Gestión de Anexo y Respuestas:p2:e', 'Gestión de Fases de Anexo:p1:w', label='Registrar Fase', labelfontsize='8.0')

# Renderizar y mostrar el diagrama
dot.render(f'{BASE_PATH}/diagrama_componentes_sistema_integral_familias_igualitarias', format='png', cleanup=True)
display(Image(filename=f'{BASE_PATH}/diagrama_componentes_sistema_integral_familias_igualitarias.png'))

# %% [markdown]
# #### `» 3.2 Cedif`

# %%
from graphviz import Digraph
from IPython.display import display, Image

# Crear el objeto Digraph
dot = Digraph(
    comment='Diagrama de Componentes - Sistema Integral de Cedif',
    format='png',
    graph_attr={
        'rankdir': 'TB',
        'bgcolor': 'transparent',
        'fontname': 'Arial',
        'fontsize': '12',
    },
    node_attr={
        'shape': 'component',
        'style': 'filled,rounded',
        'fillcolor': '#f9f9f9',
        'color': '#555555',
        'fontname': 'Arial',
        'fontsize': '10',
    },
    edge_attr={
        'color': '#777777',
        'arrowsize': '0.7',
        'fontname': 'Arial',
        'fontsize': '8',
    }
)

# Añadir el contenedor principal
with dot.subgraph(name='cluster_main_system') as c:
    c.attr(label='Sistema Integral de Cedif', style='filled', color='lightgrey', fontsize='14', fontname='Arial Bold')

    # Añadir componentes con sus puertos
    c.node('Gestión de Servicios', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFD700"><b>Gestión de Servicios</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Servicio</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Servicio</td></tr>\n'
           '</table>>')

    c.node('Gestión de Profesiones', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#87CEFA"><b>Gestión de Profesiones</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Profesión</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Profesión</td></tr>\n'
           '</table>>')

    c.node('Gestión de Grupos Sociales', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#98FB98"><b>Gestión de Grupos Sociales</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Grupo Social</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Grupo Social</td></tr>\n'
           '</table>>')

    c.node('Gestión de Familias', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFB6C1"><b>Gestión de Familias</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Familia</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Familia</td></tr>\n'
           '</table>>')

    c.node('Gestión de Motivos de Referencia', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#F0E68C"><b>Gestión de Motivos de Referencia</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Motivo</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Motivo</td></tr>\n'
           '</table>>')

    c.node('Gestión de Anexo y Respuestas', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#E0FFFF"><b>Gestión de Anexo y Respuestas</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Anexo</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Anexo</td></tr>\n'
           '</table>>')

    c.node('Gestión de Ubigeo', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#90EE90"><b>Gestión de Ubigeo</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Ubicación</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Ubicación</td></tr>\n'
           '</table>>')

    c.node('Gestión de Talleres y Sesiones', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFE4B5"><b>Gestión de Talleres y Sesiones</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Programar Taller</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Registrar Sesión</td></tr>\n'
           '</table>>')

    c.node('Gestión de PATFAM', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFDEAD"><b>Gestión de PATFAM</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar PATFAM</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar PATFAM</td></tr>\n'
           '</table>>')

    c.node('Gestión de Ejecución de Sesiones', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#D8BFD8"><b>Gestión de Ejecución de Sesiones</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Ejecutar Sesión</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Registrar Asistencia</td></tr>\n'
           '</table>>')

    c.node('Gestión de Actas', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#FFDAB9"><b>Gestión de Actas</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Acta</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Acta</td></tr>\n'
           '</table>>')

    c.node('Gestión de Códigos de Familias', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#EEE8AA"><b>Gestión de Códigos de Familias</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Código</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Código</td></tr>\n'
           '</table>>')

    c.node('Gestión de Fases de Anexo', '<<table border="0" cellborder="1" cellspacing="0">\n'
           '   <tr><td colspan="2" bgcolor="#F5DEB3"><b>Gestión de Fases de Anexo</b></td></tr>\n'
           '   <tr><td port="p1" bgcolor="#e6f3ff">Registrar Fase</td></tr>\n'
           '   <tr><td port="p2" bgcolor="#e6f3ff">Actualizar Fase</td></tr>\n'
           '</table>>')

# Añadir actor
dot.node('Responsable', '<<table border="0" cellborder="0">\n'
         '   <tr><td><font point-size="10">\u263A Responsable de Intervención Profesional</font></td></tr>\n'
         '</table>>', shape='plaintext')

# Añadir conexiones entre componentes
dot.edge('Responsable:e', 'Gestión de Servicios:p1:w', label='Ingresar Servicios', labelfontsize='8.0')
dot.edge('Responsable:e', 'Gestión de Talleres y Sesiones:p1:w', label='Programar Taller', labelfontsize='8.0')
dot.edge('Responsable:e', 'Gestión de PATFAM:p1:w', label='Registrar PATFAM', labelfontsize='8.0')

dot.edge('Gestión de Familias:p2:e', 'Gestión de Motivos de Referencia:p1:w', label='Registrar Motivo', labelfontsize='8.0')
dot.edge('Gestión de Talleres y Sesiones:p2:e', 'Gestión de Ejecución de Sesiones:p1:w', label='Ejecutar Sesión', labelfontsize='8.0')
dot.edge('Gestión de Ejecución de Sesiones:p2:e', 'Gestión de Actas:p1:w', label='Registrar Acta', labelfontsize='8.0')
dot.edge('Gestión de Anexo y Respuestas:p2:e', 'Gestión de Fases de Anexo:p1:w', label='Registrar Fase', labelfontsize='8.0')

# Renderizar y mostrar el diagrama
dot.render(f'{BASE_PATH}/diagrama_componentes_sistema_integral_cedif', format='png', cleanup=True)
display(Image(filename=f'{BASE_PATH}/diagrama_componentes_sistema_integral_cedif.png'))

# %% [markdown]
# ## `░ 4. Generar diagrama de Clases`

# %% [markdown]
# #### `» 4.1 Familias Igualitarias`

# %%
from graphviz import Digraph
from IPython.display import display

# Crear el diagrama con configuración profesional
dot = Digraph(comment='Diagrama de Clases - Familias Igualitarias', format='png')
dot.attr(rankdir='TB', splines='ortho', nodesep='0.8', ranksep='1.2')  # margin='left-right,top-bottom', pad es adicional
dot.attr('node', shape='record', style='filled', fillcolor='lightblue', 
         fontname='Arial', fontsize='10')
dot.attr('edge', fontname='Arial', fontsize='9', color='#333333')


# SSI_SERVICIOS_INABIF
dot.node('SSI_SERVICIOS_INABIF', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_SERVICIOS_INABIF</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SI_ID_SERVICIO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">SI_FECHA_REGISTRO: DATE</TD></TR>
<TR><TD ALIGN="LEFT">SI_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">SI_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PROFESION
dot.node('SSI_PROFESION', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PROFESION</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PR_ID_PROFESION: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PR_NOMBRE: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">PR_ESTADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_GRUPO_SOCIAL
dot.node('SSI_GRUPO_SOCIAL', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_GRUPO_SOCIAL</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>GR_ID_GRUPO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">GR_DESCRIPCION: VARCHAR2(200)</TD></TR>
<TR><TD ALIGN="LEFT">GR_FEC_REGISTRA: DATE</TD></TR>
<TR><TD ALIGN="LEFT">ESTADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ZONA_INTERVENCION
dot.node('SSI_ZONA_INTERVENCION', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ZONA_INTERVENCION</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>ZO_ID_ZONA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">INS_ID_INSTITUCION: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UOR_ID_UNIDADORG: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">UBI_ID_UBIGEO: CHAR(6)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_COD_TIPO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_DESCRIPCION: VARCHAR2(350)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_EQUIPO_TRABAJO
dot.node('SSI_EQUIPO_TRABAJO', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_EQUIPO_TRABAJO</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>EQ_ID_EQUIPO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">ZO_ID_ZONA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PER_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PR_ID_PROFESION: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">EQ_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">EQ_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ALIADOS
dot.node('SSI_ALIADOS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ALIADOS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AL_ID_ALIADO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">ZO_ID_ZONA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">INS_ID_INSTITUCION: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">GR_ID_GRUPO_SOCIAL: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AL_GRADO_INFLUENCIA: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AL_INTERES_SERVICIO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AL_RESULTADO: NUMBER(2)</TD></TR>
<TR><TD ALIGN="LEFT">AL_POSICION: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">AL_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AL_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_CONTACTO
dot.node('SSI_CONTACTO', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_CONTACTO</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>CO_ID_CONTACTO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">AL_ID_ALIADO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">ID_TIPDOC: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PA_ID_NACIONALIDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">CO_NUMERO_DOC: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">CO_NOMBRES: VARCHAR2(350)</TD></TR>
<TR><TD ALIGN="LEFT">CO_PRIMER_APE: VARCHAR2(350)</TD></TR>
<TR><TD ALIGN="LEFT">CO_SEGUNDO_APE: VARCHAR2(350)</TD></TR>
<TR><TD ALIGN="LEFT">CO_TELEFONO: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">CO_CORREO: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">CO_DIRECCION: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">CO_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CO_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_POTENCIALES_FAMILIAS
dot.node('SSI_POTENCIALES_FAMILIAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#E74C3C" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_POTENCIALES_FAMILIAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PF_ID_FAMILIA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_COD_FAMILIA: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_ID_ZONA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AL_ID_ALIADO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UO_ID_UNIDADORGANICA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PER_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PF_OBSERVACIONES: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PF_FAMILIA_APTA: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_MOTIVO_REFERENCIA
dot.node('SSI_MOTIVO_REFERENCIA', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_MOTIVO_REFERENCIA</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>MR_ID_MOTIVO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">MR_DESCRIPCION: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">MR_FECHA_REGISTRA: DATE</TD></TR>
<TR><TD ALIGN="LEFT">MR_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_FAMILIA_MOTIVO_REFERENCIA
dot.node('SSI_FAMILIA_MOTIVO_REFERENCIA', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#9B59B6" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_FAMILIA_MOTIVO_REFERENCIA</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>FMR_ID_FMR: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">MR_ID_MOTIVO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">FMR_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FMR_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_FAMILIA_INTEGRANTES
dot.node('SSI_FAMILIA_INTEGRANTES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#E74C3C" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_FAMILIA_INTEGRANTES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>FI_ID_INTEGRANTE: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PF_INTEGRANTE_APTO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CA_ID_TIPDOC: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_NUMERO_DOC: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">FI_NOMBRES: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">FI_PRIMER_APE: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">FI_SEGUNDO_APE: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">FI_FEC_NAC: DATE</TD></TR>
<TR><TD ALIGN="LEFT">FI_EDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_TELEFONO: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">FI_CORREO: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">UBI_ID_UBIGEO: CHAR(6)</TD></TR>
<TR><TD ALIGN="LEFT">FI_DIRECCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">FI_CUIDADOR: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FI_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ANEXOS_PREGUNTAS
dot.node('SSI_ANEXOS_PREGUNTAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#16A085" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ANEXOS_PREGUNTAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AP_ID_PREGUNTA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AP_NUM_ANEXO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_NUM_GRUPO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_NUM_PREGUNTA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_PREGUNTA: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AP_OPCIONES: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AP_TIPO_CONTROL: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">AP_CONDICION_SI: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_CONDICION_NO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ANEXOS_RESPUESTAS
dot.node('SSI_ANEXOS_RESPUESTAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#16A085" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ANEXOS_RESPUESTAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AR_ID_RESPUESTA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">FI_ID_INTEGRANTE: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AR_DESTINATARIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_ID_PREGUNTA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AR_RESPUESTA: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AR_RESPUESTA_BLOB: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">SF_ID_FASE: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PR_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AR_OBSERVACION: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AR_ELIMINADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AN_ESTADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_UBIGEO_NOMBRES
dot.node('SSI_UBIGEO_NOMBRES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#F39C12" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_UBIGEO_NOMBRES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>U_ID_UBIGEO: CHAR(6)</U></TD></TR>
<TR><TD ALIGN="LEFT">U_ID_DEPARTAMENTO: CHAR(2)</TD></TR>
<TR><TD ALIGN="LEFT">U_DEPARTAMENTO: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">U_ID_PROVINCIA: CHAR(2)</TD></TR>
<TR><TD ALIGN="LEFT">U_PROVINCIA: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">U_ID_DISTRITO: CHAR(2)</TD></TR>
<TR><TD ALIGN="LEFT">U_DISTRITO: VARCHAR2(100)</TD></TR>
</TABLE>>''')

# SSI_OBJETIVOS_ESPECIFICOS
dot.node('SSI_OBJETIVOS_ESPECIFICOS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_OBJETIVOS_ESPECIFICOS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>OE_ID_OBJETIVO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">OE_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">OE_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">OE_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">OE_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_MODULOS
dot.node('SSI_MODULOS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_MODULOS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>MO_ID_MODULO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">MO_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">MO_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">MO_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">MO_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_UNIDADES
dot.node('SSI_UNIDADES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_UNIDADES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>UN_ID_UNIDAD: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">UN_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">UN_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">UN_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">UN_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_TEMAS
dot.node('SSI_TEMAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_TEMAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>TE_ID_TEMA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">UN_ID_UNIDAD: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">TE_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TE_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TE_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">TE_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_UNIDAD_SESIONES
dot.node('SSI_UNIDAD_SESIONES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_UNIDAD_SESIONES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SE_ID_SESION: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">UN_ID_UNIDAD: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">SE_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">SE_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">SE_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">SE_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_TALLERES
dot.node('SSI_TALLERES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_TALLERES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>TA_ID_TALLER: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SE_ID_SESION: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TE_ID_TEMA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TA_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TA_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TA_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">TA_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PATFAM
dot.node('SSI_PATFAM', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#8E44AD" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PATFAM</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PA_ID_PATFAM: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PA_MOTIVO_REFERENCIA: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_DIAGNOSTICO: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_NOMBRE_CUIDADOR: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_ZONA_INTERVENCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PA_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_DET_PATFAM
dot.node('SSI_DET_PATFAM', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#8E44AD" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_DET_PATFAM</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>DP_ID_DET_PATFAM: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PA_ID_PATFAM: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UN_ID_UNIDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TE_ID_TEMA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SE_ID_SESION: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TA_ID_TALLER: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">DP_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">DP_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_EJECUCION_SESIONES
dot.node('SSI_EJECUCION_SESIONES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#D35400" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_EJECUCION_SESIONES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>ES_ID_EJECUCION: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">DP_ID_DET_PATFAM: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">SE_ID_SESION: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PR_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">CA_ID_MODALIDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">ES_REALIZO_SESION: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ES_FEC_HORA_INI: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">ES_FEC_HORA_FIN: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">ES_OBSERVACIONES: VARCHAR(500)</TD></TR>
<TR><TD ALIGN="LEFT">ES_ANEXO: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">ES_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ES_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_EJEC_SESION_INTEGRANTES
dot.node('SSI_EJEC_SESION_INTEGRANTES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#D35400" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_EJEC_SESION_INTEGRANTES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SI_ID_SESION_INTEGRANTE: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">ES_ID_EJECUCION: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">FI_ID_INTEGRANTE: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">SI_ASISTIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SI_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">SI_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PROG_TALLERES
dot.node('SSI_PROG_TALLERES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#C0392B" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PROG_TALLERES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PT_ID_PROG_TALLER: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">TA_ID_TALLER: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PE_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UO_ID_UNIDADORG: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PT_TEMA: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PT_LUGAR_TALLER: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PT_FEC_HORA_INI: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">PT_FEC_HORA_FIN: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">PT_ANEXO: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">PT_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PT_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PROG_TALLER_FAMILIAS
dot.node('SSI_PROG_TALLER_FAMILIAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#C0392B" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PROG_TALLER_FAMILIAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PD_ID_PROG_TALL_FAM: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PT_ID_PROG_TALLER: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">DP_ID_DET_PATFAM: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PD_ASISTIO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PD_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PD_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ANEXO_FASES
dot.node('SSI_ANEXO_FASES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#16A085" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ANEXO_FASES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SF_ID_FASE: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SF_NOMBRE: VARCHAR2(30)</TD></TR>
<TR><TD ALIGN="LEFT">SF_ID_SERVICIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SF_NUM_ANEXO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SF_ORDEN: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FF_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ACTAS
dot.node('SSI_ACTAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#34495E" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ACTAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AC_ID_ACTA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">AL_ID_ALIADO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">CA_ID_TIPO_ACTA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AC_ANEXO: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">AC_ANEXO_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">AC_FECHA_ACTA: DATE</TD></TR>
<TR><TD ALIGN="LEFT">AC_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AC_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_CODIGOS_FAMILIAS
dot.node('SSI_CODIGOS_FAMILIAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#7F8C8D" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_CODIGOS_FAMILIAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>CF_ID_CODIGO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_ID_INTEGRANTE: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">CF_CODIGO: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">CF_TIPO_CODIGO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CF_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# ===============================
# RELACIONES (FOREIGN KEYS)
# ===============================

# Relaciones desde SSI_ZONA_INTERVENCION
dot.edge('SSI_ZONA_INTERVENCION', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Relaciones desde SSI_EQUIPO_TRABAJO
dot.edge('SSI_EQUIPO_TRABAJO', 'SSI_ZONA_INTERVENCION', label='ZO_ID_ZONA')
dot.edge('SSI_EQUIPO_TRABAJO', 'SSI_PROFESION', label='PR_ID_PROFESION')

# Relaciones desde SSI_ALIADOS
dot.edge('SSI_ALIADOS', 'SSI_ZONA_INTERVENCION', label='ZO_ID_ZONA')
dot.edge('SSI_ALIADOS', 'SSI_GRUPO_SOCIAL', label='GR_ID_GRUPO_SOCIAL')

# Relaciones desde SSI_CONTACTO
dot.edge('SSI_CONTACTO', 'SSI_ALIADOS', label='AL_ID_ALIADO')

# Relaciones desde SSI_POTENCIALES_FAMILIAS
dot.edge('SSI_POTENCIALES_FAMILIAS', 'SSI_ZONA_INTERVENCION', label='ZO_ID_ZONA')

# Relaciones desde SSI_FAMILIA_MOTIVO_REFERENCIA
dot.edge('SSI_FAMILIA_MOTIVO_REFERENCIA', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')
dot.edge('SSI_FAMILIA_MOTIVO_REFERENCIA', 'SSI_MOTIVO_REFERENCIA', label='MR_ID_MOTIVO')

# Relaciones desde SSI_FAMILIA_INTEGRANTES
dot.edge('SSI_FAMILIA_INTEGRANTES', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_ANEXOS_PREGUNTAS
dot.edge('SSI_ANEXOS_PREGUNTAS', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Relaciones desde SSI_ANEXOS_RESPUESTAS
dot.edge('SSI_ANEXOS_RESPUESTAS', 'SSI_ANEXOS_PREGUNTAS', label='AP_ID_PREGUNTA')
dot.edge('SSI_ANEXOS_RESPUESTAS', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_OBJETIVOS_ESPECIFICOS
dot.edge('SSI_OBJETIVOS_ESPECIFICOS', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Relaciones desde SSI_MODULOS
dot.edge('SSI_MODULOS', 'SSI_OBJETIVOS_ESPECIFICOS', label='OE_ID_OBJETIVO')

# Relaciones desde SSI_UNIDADES
dot.edge('SSI_UNIDADES', 'SSI_MODULOS', label='MO_ID_MODULO')

# Relaciones desde SSI_TEMAS
dot.edge('SSI_TEMAS', 'SSI_UNIDADES', label='UN_ID_UNIDAD')

# Relaciones desde SSI_UNIDAD_SESIONES
dot.edge('SSI_UNIDAD_SESIONES', 'SSI_UNIDADES', label='UN_ID_UNIDAD')
dot.edge('SSI_UNIDAD_SESIONES', 'SSI_OBJETIVOS_ESPECIFICOS', label='OE_ID_OBJETIVO')

# Relaciones desde SSI_PATFAM
dot.edge('SSI_PATFAM', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_DET_PATFAM
dot.edge('SSI_DET_PATFAM', 'SSI_PATFAM', label='PA_ID_PATFAM')

# Relaciones desde SSI_EJECUCION_SESIONES
dot.edge('SSI_EJECUCION_SESIONES', 'SSI_DET_PATFAM', label='DP_ID_DET_PATFAM')
dot.edge('SSI_EJECUCION_SESIONES', 'SSI_UNIDAD_SESIONES', label='SE_ID_SESION')

# Relaciones desde SSI_EJEC_SESION_INTEGRANTES
dot.edge('SSI_EJEC_SESION_INTEGRANTES', 'SSI_EJECUCION_SESIONES', label='ES_ID_EJECUCION')
dot.edge('SSI_EJEC_SESION_INTEGRANTES', 'SSI_FAMILIA_INTEGRANTES', label='FI_ID_INTEGRANTE')

# Relaciones desde SSI_PROG_TALLERES
dot.edge('SSI_PROG_TALLERES', 'SSI_TALLERES', label='TA_ID_TALLER')

# Relaciones desde SSI_PROG_TALLER_FAMILIAS
dot.edge('SSI_PROG_TALLER_FAMILIAS', 'SSI_PROG_TALLERES', label='PT_ID_PROG_TALLER')
dot.edge('SSI_PROG_TALLER_FAMILIAS', 'SSI_DET_PATFAM', label='DP_ID_DET_PATFAM')
dot.edge('SSI_PROG_TALLER_FAMILIAS', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_ACTAS
dot.edge('SSI_ACTAS', 'SSI_ALIADOS', label='AL_ID_ALIADO')

# Relaciones desde SSI_CODIGOS_FAMILIAS
dot.edge('SSI_CODIGOS_FAMILIAS', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Renderizar y mostrar el diagrama
# display(dot)

# Renderizar y mostrar el diagrama
dot.render(filename=f'{BASE_PATH}/diagrama_clases_familias_igualitarias_v1', format='png', cleanup=True)
# display(Image(filename=f'{BASE_PATH}/diagrama_clases_servicios_sociales.png'))

# %% [markdown]
# #### `» 4.2 Cedif`

# %%
from graphviz import Digraph
from IPython.display import display

# Crear el diagrama con configuración profesional
dot = Digraph(comment='Diagrama de Clases - CEDIF', format='png')
dot.attr(rankdir='TB', splines='ortho', nodesep='0.8', ranksep='1.2')  # margin='left-right,top-bottom', pad es adicional
dot.attr('node', shape='record', style='filled', fillcolor='lightblue', 
         fontname='Arial', fontsize='10')
dot.attr('edge', fontname='Arial', fontsize='9', color='#333333')


# SSI_SERVICIOS_INABIF
dot.node('SSI_SERVICIOS_INABIF', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_SERVICIOS_INABIF</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SI_ID_SERVICIO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">SI_FECHA_REGISTRO: DATE</TD></TR>
<TR><TD ALIGN="LEFT">SI_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">SI_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_CEDIF(Unidades Orgánicas)
dot.node('SSI_ZONA_INTERVENCION', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ZONA_INTERVENCION</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>ZO_ID_ZONA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">INS_ID_INSTITUCION: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UOR_ID_UNIDADORG: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">UBI_ID_UBIGEO: CHAR(6)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_COD_TIPO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_DESCRIPCION: VARCHAR2(350)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_POTENCIALES_FAMILIAS
dot.node('SSI_POTENCIALES_FAMILIAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#E74C3C" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_POTENCIALES_FAMILIAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PF_ID_FAMILIA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_COD_FAMILIA: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">ZO_ID_ZONA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AL_ID_ALIADO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UO_ID_UNIDADORGANICA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PER_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PF_OBSERVACIONES: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PF_FAMILIA_APTA: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_MOTIVO_REFERENCIA
dot.node('SSI_MOTIVO_REFERENCIA', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#4A90E2" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_MOTIVO_REFERENCIA</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>MR_ID_MOTIVO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">MR_DESCRIPCION: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">MR_FECHA_REGISTRA: DATE</TD></TR>
<TR><TD ALIGN="LEFT">MR_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_FAMILIA_MOTIVO_REFERENCIA
dot.node('SSI_FAMILIA_MOTIVO_REFERENCIA', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#9B59B6" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_FAMILIA_MOTIVO_REFERENCIA</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>FMR_ID_FMR: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">MR_ID_MOTIVO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">FMR_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FMR_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_FAMILIA_INTEGRANTES
dot.node('SSI_FAMILIA_INTEGRANTES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#E74C3C" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_FAMILIA_INTEGRANTES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>FI_ID_INTEGRANTE: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PF_INTEGRANTE_APTO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CA_ID_TIPDOC: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_NUMERO_DOC: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">FI_NOMBRES: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">FI_PRIMER_APE: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">FI_SEGUNDO_APE: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">FI_FEC_NAC: DATE</TD></TR>
<TR><TD ALIGN="LEFT">FI_EDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_TELEFONO: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">FI_CORREO: VARCHAR2(250)</TD></TR>
<TR><TD ALIGN="LEFT">UBI_ID_UBIGEO: CHAR(6)</TD></TR>
<TR><TD ALIGN="LEFT">FI_DIRECCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">FI_CUIDADOR: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FI_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ANEXOS_PREGUNTAS
dot.node('SSI_ANEXOS_PREGUNTAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#16A085" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ANEXOS_PREGUNTAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AP_ID_PREGUNTA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AP_NUM_ANEXO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_NUM_GRUPO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_NUM_PREGUNTA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_PREGUNTA: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AP_OPCIONES: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AP_TIPO_CONTROL: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">AP_CONDICION_SI: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_CONDICION_NO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ANEXOS_RESPUESTAS
dot.node('SSI_ANEXOS_RESPUESTAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#16A085" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ANEXOS_RESPUESTAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AR_ID_RESPUESTA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">FI_ID_INTEGRANTE: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AR_DESTINATARIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AP_ID_PREGUNTA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">AR_RESPUESTA: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AR_RESPUESTA_BLOB: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">SF_ID_FASE: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PR_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AR_OBSERVACION: VARCHAR2(4000)</TD></TR>
<TR><TD ALIGN="LEFT">AR_ELIMINADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AN_ESTADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_UBIGEO_NOMBRES
dot.node('SSI_UBIGEO_NOMBRES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#F39C12" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_UBIGEO_NOMBRES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>U_ID_UBIGEO: CHAR(6)</U></TD></TR>
<TR><TD ALIGN="LEFT">U_ID_DEPARTAMENTO: CHAR(2)</TD></TR>
<TR><TD ALIGN="LEFT">U_DEPARTAMENTO: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">U_ID_PROVINCIA: CHAR(2)</TD></TR>
<TR><TD ALIGN="LEFT">U_PROVINCIA: VARCHAR2(100)</TD></TR>
<TR><TD ALIGN="LEFT">U_ID_DISTRITO: CHAR(2)</TD></TR>
<TR><TD ALIGN="LEFT">U_DISTRITO: VARCHAR2(100)</TD></TR>
</TABLE>>''')

# SSI_OBJETIVOS_ESPECIFICOS
dot.node('SSI_OBJETIVOS_ESPECIFICOS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_OBJETIVOS_ESPECIFICOS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>OE_ID_OBJETIVO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">OE_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">OE_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">OE_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">OE_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_MODULOS
dot.node('SSI_MODULOS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_MODULOS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>MO_ID_MODULO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">MO_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">MO_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">MO_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">MO_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_UNIDADES
dot.node('SSI_UNIDADES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_UNIDADES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>UN_ID_UNIDAD: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">UN_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">UN_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">UN_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">UN_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_TEMAS
dot.node('SSI_TEMAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_TEMAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>TE_ID_TEMA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">UN_ID_UNIDAD: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">TE_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TE_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TE_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">TE_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_UNIDAD_SESIONES
dot.node('SSI_UNIDAD_SESIONES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_UNIDAD_SESIONES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SE_ID_SESION: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">UN_ID_UNIDAD: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">SE_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">SE_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">SE_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">SE_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_TALLERES
dot.node('SSI_TALLERES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#27AE60" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_TALLERES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>TA_ID_TALLER: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SE_ID_SESION: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TE_ID_TEMA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TA_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TA_DESCRIPCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">TA_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">TA_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PATFAM
dot.node('SSI_PATFAM', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#8E44AD" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PATFAM</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PA_ID_PATFAM: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PA_MOTIVO_REFERENCIA: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_DIAGNOSTICO: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_NOMBRE_CUIDADOR: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_ZONA_INTERVENCION: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PA_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PA_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_DET_PATFAM
dot.node('SSI_DET_PATFAM', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#8E44AD" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_DET_PATFAM</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>DP_ID_DET_PATFAM: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PA_ID_PATFAM: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">OE_ID_OBJETIVO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">MO_ID_MODULO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UN_ID_UNIDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TE_ID_TEMA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SE_ID_SESION: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">TA_ID_TALLER: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">DP_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">DP_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_EJECUCION_SESIONES
dot.node('SSI_EJECUCION_SESIONES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#D35400" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_EJECUCION_SESIONES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>ES_ID_EJECUCION: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">DP_ID_DET_PATFAM: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">SE_ID_SESION: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PR_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">CA_ID_MODALIDAD: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">ES_REALIZO_SESION: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ES_FEC_HORA_INI: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">ES_FEC_HORA_FIN: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">ES_OBSERVACIONES: VARCHAR(500)</TD></TR>
<TR><TD ALIGN="LEFT">ES_ANEXO: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">ES_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">ES_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_EJEC_SESION_INTEGRANTES
dot.node('SSI_EJEC_SESION_INTEGRANTES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#D35400" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_EJEC_SESION_INTEGRANTES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SI_ID_SESION_INTEGRANTE: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">ES_ID_EJECUCION: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">FI_ID_INTEGRANTE: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">SI_ASISTIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SI_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">SI_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PROG_TALLERES
dot.node('SSI_PROG_TALLERES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#C0392B" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PROG_TALLERES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PT_ID_PROG_TALLER: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">TA_ID_TALLER: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PE_ID_PERSONAL: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">UO_ID_UNIDADORG: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">PT_TEMA: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PT_LUGAR_TALLER: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">PT_FEC_HORA_INI: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">PT_FEC_HORA_FIN: TIMESTAMP</TD></TR>
<TR><TD ALIGN="LEFT">PT_ANEXO: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">PT_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PT_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_PROG_TALLER_FAMILIAS
dot.node('SSI_PROG_TALLER_FAMILIAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#C0392B" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_PROG_TALLER_FAMILIAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>PD_ID_PROG_TALL_FAM: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">PT_ID_PROG_TALLER: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">DP_ID_DET_PATFAM: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PD_ASISTIO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PD_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">PD_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ANEXO_FASES
dot.node('SSI_ANEXO_FASES', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#16A085" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ANEXO_FASES</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>SF_ID_FASE: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SF_NOMBRE: VARCHAR2(30)</TD></TR>
<TR><TD ALIGN="LEFT">SF_ID_SERVICIO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SF_NUM_ANEXO: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">SF_ORDEN: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FF_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">FF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_ACTAS
dot.node('SSI_ACTAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#34495E" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_ACTAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>AC_ID_ACTA: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">AL_ID_ALIADO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">CA_ID_TIPO_ACTA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">AC_ANEXO: BLOB</TD></TR>
<TR><TD ALIGN="LEFT">AC_ANEXO_NOMBRE: VARCHAR2(500)</TD></TR>
<TR><TD ALIGN="LEFT">AC_FECHA_ACTA: DATE</TD></TR>
<TR><TD ALIGN="LEFT">AC_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">AC_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# SSI_CODIGOS_FAMILIAS
dot.node('SSI_CODIGOS_FAMILIAS', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
<TR><TD BGCOLOR="#7F8C8D" ALIGN="CENTER"><FONT COLOR="white"><B>SSI_CODIGOS_FAMILIAS</B></FONT></TD></TR>
<TR><TD ALIGN="LEFT"><U>CF_ID_CODIGO: NUMBER</U></TD></TR>
<TR><TD ALIGN="LEFT">SI_ID_SERVICIO: NUMBER (FK)</TD></TR>
<TR><TD ALIGN="LEFT">PF_ID_FAMILIA: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">FI_ID_INTEGRANTE: NUMBER</TD></TR>
<TR><TD ALIGN="LEFT">CF_CODIGO: VARCHAR2(50)</TD></TR>
<TR><TD ALIGN="LEFT">CF_TIPO_CODIGO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CF_ESTADO: NUMBER(1)</TD></TR>
<TR><TD ALIGN="LEFT">CF_ELIMINADO: NUMBER(1)</TD></TR>
</TABLE>>''')

# ===============================
# RELACIONES (FOREIGN KEYS)
# ===============================

# Relaciones desde SSI_ZONA_INTERVENCION
dot.edge('SSI_ZONA_INTERVENCION', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Relaciones desde SSI_POTENCIALES_FAMILIAS
dot.edge('SSI_POTENCIALES_FAMILIAS', 'SSI_ZONA_INTERVENCION', label='ZO_ID_ZONA')

# Relaciones desde SSI_FAMILIA_MOTIVO_REFERENCIA
dot.edge('SSI_FAMILIA_MOTIVO_REFERENCIA', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')
dot.edge('SSI_FAMILIA_MOTIVO_REFERENCIA', 'SSI_MOTIVO_REFERENCIA', label='MR_ID_MOTIVO')

# Relaciones desde SSI_FAMILIA_INTEGRANTES
dot.edge('SSI_FAMILIA_INTEGRANTES', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_ANEXOS_PREGUNTAS
dot.edge('SSI_ANEXOS_PREGUNTAS', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Relaciones desde SSI_ANEXOS_RESPUESTAS
dot.edge('SSI_ANEXOS_RESPUESTAS', 'SSI_ANEXOS_PREGUNTAS', label='AP_ID_PREGUNTA')
dot.edge('SSI_ANEXOS_RESPUESTAS', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_OBJETIVOS_ESPECIFICOS
dot.edge('SSI_OBJETIVOS_ESPECIFICOS', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Relaciones desde SSI_MODULOS
dot.edge('SSI_MODULOS', 'SSI_OBJETIVOS_ESPECIFICOS', label='OE_ID_OBJETIVO')

# Relaciones desde SSI_UNIDADES
dot.edge('SSI_UNIDADES', 'SSI_MODULOS', label='MO_ID_MODULO')

# Relaciones desde SSI_TEMAS
dot.edge('SSI_TEMAS', 'SSI_UNIDADES', label='UN_ID_UNIDAD')

# Relaciones desde SSI_UNIDAD_SESIONES
dot.edge('SSI_UNIDAD_SESIONES', 'SSI_UNIDADES', label='UN_ID_UNIDAD')
dot.edge('SSI_UNIDAD_SESIONES', 'SSI_OBJETIVOS_ESPECIFICOS', label='OE_ID_OBJETIVO')

# Relaciones desde SSI_PATFAM
dot.edge('SSI_PATFAM', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_DET_PATFAM
dot.edge('SSI_DET_PATFAM', 'SSI_PATFAM', label='PA_ID_PATFAM')

# Relaciones desde SSI_EJECUCION_SESIONES
dot.edge('SSI_EJECUCION_SESIONES', 'SSI_DET_PATFAM', label='DP_ID_DET_PATFAM')
dot.edge('SSI_EJECUCION_SESIONES', 'SSI_UNIDAD_SESIONES', label='SE_ID_SESION')

# Relaciones desde SSI_EJEC_SESION_INTEGRANTES
dot.edge('SSI_EJEC_SESION_INTEGRANTES', 'SSI_EJECUCION_SESIONES', label='ES_ID_EJECUCION')
dot.edge('SSI_EJEC_SESION_INTEGRANTES', 'SSI_FAMILIA_INTEGRANTES', label='FI_ID_INTEGRANTE')

# Relaciones desde SSI_PROG_TALLERES
dot.edge('SSI_PROG_TALLERES', 'SSI_TALLERES', label='TA_ID_TALLER')

# Relaciones desde SSI_PROG_TALLER_FAMILIAS
dot.edge('SSI_PROG_TALLER_FAMILIAS', 'SSI_PROG_TALLERES', label='PT_ID_PROG_TALLER')
dot.edge('SSI_PROG_TALLER_FAMILIAS', 'SSI_DET_PATFAM', label='DP_ID_DET_PATFAM')
dot.edge('SSI_PROG_TALLER_FAMILIAS', 'SSI_POTENCIALES_FAMILIAS', label='PF_ID_FAMILIA')

# Relaciones desde SSI_ACTAS
dot.edge('SSI_ACTAS', 'SSI_ALIADOS', label='AL_ID_ALIADO')

# Relaciones desde SSI_CODIGOS_FAMILIAS
dot.edge('SSI_CODIGOS_FAMILIAS', 'SSI_SERVICIOS_INABIF', label='SI_ID_SERVICIO')

# Renderizar y mostrar el diagrama
# display(dot)

# Renderizar y mostrar el diagrama
dot.render(filename=f'{BASE_PATH}/diagrama_clases_cedif_v1', format='png', cleanup=True)
# display(Image(filename=f'{BASE_PATH}/diagrama_clases_servicios_sociales.png'))

# %% [markdown]
# ### `░ 5. Generar Modelo Entidad-Relación (ER)`

# %%
from graphviz import Digraph

# Crear el objeto Digraph con ajustes para un diseño horizontal y espaciado
er_diagram = Digraph(
    comment='Modelo Entidad-Relación - SSI (Horizontal)',
    format='png',
    graph_attr={
        'dpi': '300',
        'size': '40,20!',  # Más ancho que alto
        'ratio': 'auto',   # Ajusta automáticamente el ratio
        'rankdir': 'LR',   # Diseño de izquierda a derecha (horizontal)
        'nodesep': '0.6',  # Espacio entre nodos
        'ranksep': '0.8',  # Espacio entre niveles (ranks)
    },
    node_attr={
        'fontsize': '10',
        'shape': 'record',
        'margin': '0.2',   # Padding interno moderado
    },
    edge_attr={
        'fontsize': '9',
        'arrowsize': '0.7',
    }
)

# Función para agregar tablas con espaciado interno
def add_table(dot, table_name, attributes):
    with dot.subgraph(name=f'cluster_{table_name}') as c:
        c.attr(
            label=table_name,
            style='filled,rounded',
            color='lightgrey',
            fontsize='11',
            margin='14',  # Padding externo del cluster
            labeljust='l',
            labelloc='t',
        )
        c.node(
            f'{table_name}_title',
            label=table_name,
            shape='note',
            style='filled,rounded',
            fillcolor='lightblue',
            fontsize='12',
            margin='0.2',  # Padding interno del título
        )
        for attr in attributes:
            c.node(
                f'{table_name}_{attr}',
                label=attr,
                shape='record',
                fontsize='10',
                margin='0.2',  # Padding interno de los atributos
            )
    return dot

# Función para agregar relaciones con espaciado
def add_relationship(dot, from_table, to_table, label, from_attr=None, to_attr=None):
    dot.edge(
        f'{from_table}_title',
        f'{to_table}_title',
        label=label,
        dir='forward',
        fontsize='9',
        arrowsize='0.7',
        labelfontsize='9',
        labeldistance='2.5',  # Distancia de la etiqueta al borde
        labelangle='30',      # Ángulo de la etiqueta para evitar solapamiento
    )
    return dot

# Definir tablas y atributos (mismo contenido que antes)
tables = {
    "SSI_SERVICIOS_INABIF": [
        "SI_ID_SERVICIO (PK)", "SI_NOMBRE", "SI_FECHA_REGISTRO", "SI_ESTADO", "SI_ELIMINADO"
    ],
    "SSI_PROFESION": [
        "PR_ID_PROFESION (PK)", "PR_NOMBRE", "PR_ESTADO"
    ],
    "SSI_GRUPO_SOCIAL": [
        "GR_ID_GRUPO (PK)", "GR_DESCRIPCION", "GR_FEC_REGISTRA", "ESTADO"
    ],
    "SSI_ZONA_INTERVENCION": [
        "ZO_ID_ZONA (PK)", "INS_ID_INSTITUCION", "UOR_ID_UNIDADORG", "SI_ID_SERVICIO", "UBI_ID_UBIGEO", "ZO_COD_TIPO", "ZO_DESCRIPCION", "ZO_USU_REGISTRA", "ZO_FEC_REGISTRA", "ZO_USU_ACTUALIZA", "ZO_FEC_ACTUALIZA", "ZO_ESTADO", "ZO_ELIMINADO"
    ],
    "SSI_EQUIPO_TRABAJO": [
        "EQ_ID_EQUIPO (PK)", "ZO_ID_ZONA (FK)", "PER_ID_PERSONAL", "PR_ID_PROFESION (FK)", "EQ_USU_REGISTRA", "EQ_FEC_REGISTRA", "EQ_USU_ACTUALIZA", "EQ_FEC_ACTUALIZA", "EQ_ESTADO", "EQ_ELIMINADO"
    ],
    "SSI_ALIADOS": [
        "AL_ID_ALIADO (PK)", "ZO_ID_ZONA (FK)", "INS_ID_INSTITUCION", "GR_ID_GRUPO_SOCIAL (FK)", "AL_GRADO_INFLUENCIA", "AL_INTERES_SERVICIO", "AL_RESULTADO", "AL_POSICION", "AL_USU_REGISTRA", "AL_FEC_REGISTRA", "AL_USU_ACTUALIZA", "AL_FEC_ACTUALIZA", "AL_ESTADO", "AL_ELIMINADO"
    ],
    "SSI_CONTACTO": [
        "CO_ID_CONTACTO (PK)", "AL_ID_ALIADO (FK)", "ID_TIPDOC", "PA_ID_NACIONALIDAD", "CO_NUMERO_DOC", "CO_NOMBRES", "CO_PRIMER_APE", "CO_SEGUNDO_APE", "CO_TELEFONO", "CO_CORREO", "CO_DIRECCION", "CO_USU_REGISTRA", "CO_FEC_REGISTRA", "CO_USU_ACTUALIZA", "CO_FEC_ACTUALIZA", "CO_ESTADO", "CO_ELIMINADO"
    ],
    "SSI_POTENCIALES_FAMILIAS": [
        "PF_ID_FAMILIA (PK)", "PF_COD_FAMILIA", "ZO_ID_ZONA (FK)", "AL_ID_ALIADO (FK)", "UO_ID_UNIDADORGANICA", "SI_ID_SERVICIO (FK)", "PER_ID_PERSONAL", "PF_OBSERVACIONES", "PF_FAMILIA_APTA", "PF_USU_REGISTRA", "PF_FEC_REGISTRA", "PF_USU_ACTUALIZA", "PF_FEC_ACTUALIZA", "PF_ESTADO", "PF_ELIMINADO"
    ],
    "SSI_MOTIVO_REFERENCIA": [
        "MR_ID_MOTIVO (PK)", "MR_DESCRIPCION", "MR_FECHA_REGISTRA", "MR_ESTADO", "PF_ELIMINADO"
    ],
    "SSI_FAMILIA_MOTIVO_REFERENCIA": [
        "FMR_ID_FMR (PK)", "PF_ID_FAMILIA (FK)", "MR_ID_MOTIVO (FK)", "FMR_ESTADO", "FMR_ELIMINADO"
    ],
    "SSI_FAMILIA_INTEGRANTES": [
        "FI_ID_INTEGRANTE (PK)", "PF_ID_FAMILIA (FK)", "PF_INTEGRANTE_APTO", "CA_ID_TIPDOC", "CA_ID_GRADO_INST", "CA_ID_TIPO_SEGURO", "PA_ID_NAC", "PA_ID_PAIS_NACIMIENTO", "CA_ID_PARENTESCO", "CA_ID_ESTADO_CIVIL", "CA_ID_SEXO", "CP_ID_CENTRO_POBLA", "CA_ID_OCUPACION", "CA_ID_IDIOMA", "CA_ID_DISCAPACIDAD", "CA_ID_DERIVADO_POR", "CA_ID_SERVICIO_CUIDADOR", "CA_TIENE_DISCAPACIDAD", "CA_ID_TIPO_FAMILIA", "CA_ID_ETNIA", "CA_ID_LENGUA_MATERNA", "CA_ID_TIPO_VIVIENDA", "CA_ID_UBICACION_VIVIENDA", "FI_CANT_INTEGRANTES", "FI_CANT_NNA", "FI_NUMERO_DOC", "FI_NOMBRES", "FI_PRIMER_APE", "FI_SEGUNDO_APE", "FI_APELLIDO_CASADO", "FI_FEC_NAC", "FI_EDAD", "FI_TELEFONO", "FI_CORREO", "UBI_ID_UBIGEO", "UBI_ID_DEPARTAMENTO", "UBI_ID_PROVINCIA", "UBI_ID_DISTRITO", "UBI_ID_UBIGEO_NAC", "UBI_ID_DEPARTAMENTO_NAC", "UBI_ID_PROVINCIA_NAC", "UBI_ID_DISTRITO_NAC", "FI_OBSERVACIONES", "FI_DIAGNOSTICO_MEDICO", "FI_ESTABLECIMIENTO_SALUD", "FI_DIRECCION", "FI_REFERENCIA_DOMICILIARIA", "FI_GRADO_SECCION_NNA", "FI_ANIO_ANTERIOR_PROMOVIDO", "FI_NOMBRE_INSTITUCION_EDUCATIVA", "FI_PESO", "FI_TALLA", "FI_INGRESOS_SOLES", "FI_GASTOS_SOLES", "FI_CUIDADOR", "FI_USU_REGISTRA", "FI_FEC_REGISTRA", "FI_USU_ACTUALIZA", "FI_FEC_ACTUALIZA", "FI_ESTADO", "FI_ELIMINADO"
    ],
    "SSI_ANEXOS_PREGUNTAS": [
        "AP_ID_PREGUNTA (PK)", "SI_ID_SERVICIO (FK)", "AP_NUM_ANEXO", "AP_NUM_GRUPO", "AP_NUM_PREGUNTA", "AP_PREGUNTA", "AP_OPCIONES", "AP_TIPO_CONTROL", "AP_CONDICION_SI", "AP_CONDICION_NO", "AP_FECHA_REGISTRO", "AP_FECHA_ELIMINACION", "AP_ELIMINADO"
    ],
    "SSI_ANEXOS_RESPUESTAS": [
        "AR_ID_RESPUESTA (PK)", "PF_ID_FAMILIA (FK)", "FI_ID_INTEGRANTE (FK)", "AR_DESTINATARIO", "AP_ID_PREGUNTA (FK)", "AR_RESPUESTA", "AR_RESPUESTA_BLOB", "SF_ID_FASE", "PR_ID_PERSONAL", "AR_OBSERVACION", "AR_USU_REGISTRA", "AR_FECHA_REGISTRA", "AR_USU_MODIFICA", "AR_FECHA_MODIFICA", "AR_USU_ELIMINA", "AR_FECHA_ELIMINA", "AR_ELIMINADO", "AN_ESTADO"
    ],
    "SSI_UBIGEO_NOMBRES": [
        "U_ID_UBIGEO (PK)", "U_ID_DEPARTAMENTO", "U_DEPARTAMENTO", "U_ID_PROVINCIA", "U_PROVINCIA", "U_ID_DISTRITO", "U_DISTRITO"
    ],
    "SSI_OBJETIVOS_ESPECIFICOS": [
        "OE_ID_OBJETIVO (PK)", "SI_ID_SERVICIO (FK)", "OE_NOMBRE", "OE_DESCRIPCION", "OE_USU_REGISTRA", "OE_FECHA_REGISTRA", "OE_USUARIO_ELIMINA", "OE_FECHA_ELIMINA", "OE_ESTADO", "OE_ELIMINADO"
    ],
    "SSI_MODULOS": [
        "MO_ID_MODULO (PK)", "OE_ID_OBJETIVO (FK)", "MO_NOMBRE", "MO_DESCRIPCION", "MO_USU_REGISTRA", "MO_FECHA_REGISTRA", "MO_USUARIO_ELIMINA", "MO_FECHA_ELIMINA", "MO_ESTADO", "MO_ELIMINADO"
    ],
    "SSI_UNIDADES": [
        "UN_ID_UNIDAD (PK)", "MO_ID_MODULO (FK)", "UN_NOMBRE", "UN_DESCRIPCION", "UN_USU_REGISTRA", "UN_FECHA_REGISTRA", "UN_USUARIO_ELIMINA", "UN_FECHA_ELIMINA", "UN_ESTADO", "UN_ELIMINADO"
    ],
    "SSI_TEMAS": [
        "TE_ID_TEMA (PK)", "UN_ID_UNIDAD (FK)", "TE_NOMBRE", "TE_DESCRIPCION", "TE_USU_REGISTRA", "TE_FECHA_REGISTRA", "TE_USUARIO_ELIMINA", "TE_FECHA_ELIMINA", "TE_ESTADO", "TE_ELIMINADO"
    ],
    "SSI_UNIDAD_SESIONES": [
        "SE_ID_SESION (PK)", "UN_ID_UNIDAD (FK)", "MO_ID_MODULO (FK)", "OE_ID_OBJETIVO (FK)", "SE_NOMBRE", "SE_DESCRIPCION", "SE_USU_REGISTRA", "SE_FECHA_REGISTRA", "SE_USUARIO_ELIMINA", "SE_FECHA_ELIMINA", "SE_ESTADO", "SE_ELIMINADO"
    ],
    "SSI_TALLERES": [
        "TA_ID_TALLER (PK)", "OE_ID_OBJETIVO (FK)", "SE_ID_SESION (FK)", "MO_ID_MODULO (FK)", "TE_ID_TEMA (FK)", "TA_NOMBRE", "TA_DESCRIPCION", "TA_USU_REGISTRA", "TA_FECHA_REGISTRA", "TA_USUARIO_ELIMINA", "TA_FECHA_ELIMINA", "TA_ESTADO", "TA_ELIMINADO"
    ],
    "SSI_PATFAM": [
        "PA_ID_PATFAM (PK)", "PF_ID_FAMILIA (FK)", "PA_MOTIVO_REFERENCIA", "PA_DIAGNOSTICO", "PA_NOMBRE_CUIDADOR", "PA_ZONA_INTERVENCION", "PA_USU_REGISTRA", "PA_FECHA_REGISTRA", "PA_USU_MODIFICA", "PA_FECHA_MODIFICA", "PA_USUARIO_ELIMINA", "PA_FECHA_ELIMINA", "PA_ESTADO", "PA_ELIMINADO"
    ],
    "SSI_DET_PATFAM": [
        "DP_ID_DET_PATFAM (PK)", "PA_ID_PATFAM (FK)", "OE_ID_OBJETIVO (FK)", "MO_ID_MODULO (FK)", "UN_ID_UNIDAD (FK)", "TE_ID_TEMA (FK)", "SE_ID_SESION (FK)", "TA_ID_TALLER (FK)", "DP_USU_REGISTRA", "DP_FECHA_REGISTRA", "DP_USU_MODIFICA", "DP_FECHA_MODIFICA", "DP_USUARIO_ELIMINA", "DP_FECHA_ELIMINA", "DP_ESTADO", "DP_ELIMINADO"
    ],
    "SSI_EJECUCION_SESIONES": [
        "ES_ID_EJECUCION (PK)", "DP_ID_DET_PATFAM (FK)", "SE_ID_SESION (FK)", "PR_ID_PERSONAL", "CA_ID_MODALIDAD", "ES_REALIZO_SESION", "ES_FEC_HORA_INI", "ES_FEC_HORA_FIN", "ES_INTEGRANTES_PRESENTES", "ES_INTEGRANTES_AUSENTES", "ES_PAREJA_PREPARADA_SESION", "ES_LUGAR_ESPACIO", "ES_MOTIVO_FUERA_CASA", "ES_MIEMBROS_ASEADOS", "ES_ESPACIO_ORDENADO", "ES_ESPACIO_LIMPIO", "ES_ACTIVIDADES_SON_REALIZADAS", "ES_FEC_HORA_SIGUIENTE_SESION", "ES_COMPROMISO", "ES_OBSERVACIONES", "ES_ANEXO_NOMBRE", "ES_ANEXO", "ES_USU_REGISTRA", "ES_FECHA_REGISTRA", "ES_USU_MODIFICA", "ES_FECHA_MODIFICA", "ES_USUARIO_ELIMINA", "ES_FECHA_ELIMINA", "ES_ESTADO", "ES_ELIMINADO"
    ],
    "SSI_EJEC_SESION_INTEGRANTES": [
        "SI_ID_SESION_INTEGRANTE (PK)", "ES_ID_EJECUCION (FK)", "FI_ID_INTEGRANTE (FK)", "SI_ASISTIO", "SI_USU_REGISTRA", "SI_FECHA_REGISTRA", "SI_USUARIO_ELIMINA", "SI_FECHA_ELIMINA", "SI_ESTADO", "SI_ELIMINADO"
    ],
    "SSI_PROG_TALLERES": [
        "PT_ID_PROG_TALLER (PK)", "TA_ID_TALLER (FK)", "PE_ID_PERSONAL", "UO_ID_UNIDADORG", "PT_TEMA", "PT_LUGAR_TALLER", "PT_ANEXO_NOMBRE", "PT_ANEXO", "PT_FEC_HORA_INI", "PT_FEC_HORA_FIN", "PT_USU_REGISTRA", "PT_FECHA_REGISTRA", "PT_USU_MODIFICA", "PT_FECHA_MODIFICA", "PT_USUARIO_ELIMINA", "PT_FECHA_ELIMINA", "PT_ESTADO", "PT_ELIMINADO"
    ],
    "SSI_PROG_TALLER_FAMILIAS": [
        "PD_ID_PROG_TALL_FAM (PK)", "PT_ID_PROG_TALLER (FK)", "DP_ID_DET_PATFAM (FK)", "PF_ID_FAMILIA (FK)", "PD_ASISTIO", "PD_USU_REGISTRA", "PD_FECHA_REGISTRA", "PD_USUARIO_ELIMINA", "PD_FECHA_ELIMINA", "PD_ESTADO", "PD_ELIMINADO"
    ],
    "SSI_ANEXO_FASES": [
        "SF_ID_FASE (PK)", "SF_NOMBRE", "SF_ID_SERVICIO (FK)", "SF_NUM_ANEXO", "SF_ORDEN", "FF_ESTADO", "FF_ELIMINADO", "FF_USU_REGISTRA", "FF_FEC_REGISTRA", "FF_USU_MODIFICA", "FF_FEC_MODIFICA", "FF_USU_ELIMINA", "FF_FEC_ELIMINA"
    ],
    "SSI_ACTAS": [
        "AC_ID_ACTA (PK)", "AL_ID_ALIADO (FK)", "CA_ID_TIPO_ACTA", "AC_ANEXO", "AC_ANEXO_NOMBRE", "AC_FECHA_ACTA", "AC_USU_REGISTRA", "AC_FECHA_REGISTRA", "AC_ESTADO", "AC_ELIMINADO"
    ],
    "SSI_CODIGOS_FAMILIAS": [
        "CF_ID_CODIGO (PK)", "SI_ID_SERVICIO (FK)", "PF_ID_FAMILIA (FK)", "FI_ID_INTEGRANTE (FK)", "CF_CODIGO", "CF_TIPO_CODIGO", "CF_USU_REGISTRA", "CF_FECHA_REGISTRA", "CF_ESTADO", "CF_ELIMINADO"
    ]
}

# Agregar nodos de tablas al diagrama
for table_name, attributes in tables.items():
    add_table(er_diagram, table_name, attributes)

# Agregar relaciones (mismo contenido que antes)
add_relationship(er_diagram, "SSI_ZONA_INTERVENCION", "SSI_SERVICIOS_INABIF", "1:N", "SI_ID_SERVICIO", "SI_ID_SERVICIO")
add_relationship(er_diagram, "SSI_EQUIPO_TRABAJO", "SSI_ZONA_INTERVENCION", "N:1", "ZO_ID_ZONA", "ZO_ID_ZONA")
add_relationship(er_diagram, "SSI_EQUIPO_TRABAJO", "SSI_PROFESION", "N:1", "PR_ID_PROFESION", "PR_ID_PROFESION")
add_relationship(er_diagram, "SSI_ALIADOS", "SSI_ZONA_INTERVENCION", "N:1", "ZO_ID_ZONA", "ZO_ID_ZONA")
add_relationship(er_diagram, "SSI_ALIADOS", "SSI_GRUPO_SOCIAL", "N:1", "GR_ID_GRUPO_SOCIAL", "GR_ID_GRUPO")
add_relationship(er_diagram, "SSI_CONTACTO", "SSI_ALIADOS", "N:1", "AL_ID_ALIADO", "AL_ID_ALIADO")
add_relationship(er_diagram, "SSI_POTENCIALES_FAMILIAS", "SSI_ZONA_INTERVENCION", "N:1", "ZO_ID_ZONA", "ZO_ID_ZONA")
add_relationship(er_diagram, "SSI_POTENCIALES_FAMILIAS", "SSI_ALIADOS", "N:1", "AL_ID_ALIADO", "AL_ID_ALIADO")
add_relationship(er_diagram, "SSI_FAMILIA_MOTIVO_REFERENCIA", "SSI_POTENCIALES_FAMILIAS", "N:1", "PF_ID_FAMILIA", "PF_ID_FAMILIA")
add_relationship(er_diagram, "SSI_FAMILIA_MOTIVO_REFERENCIA", "SSI_MOTIVO_REFERENCIA", "N:1", "MR_ID_MOTIVO", "MR_ID_MOTIVO")
add_relationship(er_diagram, "SSI_FAMILIA_INTEGRANTES", "SSI_POTENCIALES_FAMILIAS", "N:1", "PF_ID_FAMILIA", "PF_ID_FAMILIA")
add_relationship(er_diagram, "SSI_ANEXOS_PREGUNTAS", "SSI_SERVICIOS_INABIF", "N:1", "SI_ID_SERVICIO", "SI_ID_SERVICIO")
add_relationship(er_diagram, "SSI_ANEXOS_RESPUESTAS", "SSI_POTENCIALES_FAMILIAS", "N:1", "PF_ID_FAMILIA", "PF_ID_FAMILIA")
add_relationship(er_diagram, "SSI_ANEXOS_RESPUESTAS", "SSI_FAMILIA_INTEGRANTES", "N:1", "FI_ID_INTEGRANTE", "FI_ID_INTEGRANTE")
add_relationship(er_diagram, "SSI_ANEXOS_RESPUESTAS", "SSI_ANEXOS_PREGUNTAS", "N:1", "AP_ID_PREGUNTA", "AP_ID_PREGUNTA")
add_relationship(er_diagram, "SSI_OBJETIVOS_ESPECIFICOS", "SSI_SERVICIOS_INABIF", "N:1", "SI_ID_SERVICIO", "SI_ID_SERVICIO")
add_relationship(er_diagram, "SSI_MODULOS", "SSI_OBJETIVOS_ESPECIFICOS", "N:1", "OE_ID_OBJETIVO", "OE_ID_OBJETIVO")
add_relationship(er_diagram, "SSI_UNIDADES", "SSI_MODULOS", "N:1", "MO_ID_MODULO", "MO_ID_MODULO")
add_relationship(er_diagram, "SSI_TEMAS", "SSI_UNIDADES", "N:1", "UN_ID_UNIDAD", "UN_ID_UNIDAD")
add_relationship(er_diagram, "SSI_UNIDAD_SESIONES", "SSI_UNIDADES", "N:1", "UN_ID_UNIDAD", "UN_ID_UNIDAD")
add_relationship(er_diagram, "SSI_UNIDAD_SESIONES", "SSI_OBJETIVOS_ESPECIFICOS", "N:1", "OE_ID_OBJETIVO", "OE_ID_OBJETIVO")
add_relationship(er_diagram, "SSI_TALLERES", "SSI_OBJETIVOS_ESPECIFICOS", "N:1", "OE_ID_OBJETIVO", "OE_ID_OBJETIVO")
add_relationship(er_diagram, "SSI_TALLERES", "SSI_UNIDAD_SESIONES", "N:1", "SE_ID_SESION", "SE_ID_SESION")
add_relationship(er_diagram, "SSI_TALLERES", "SSI_MODULOS", "N:1", "MO_ID_MODULO", "MO_ID_MODULO")
add_relationship(er_diagram, "SSI_TALLERES", "SSI_TEMAS", "N:1", "TE_ID_TEMA", "TE_ID_TEMA")
add_relationship(er_diagram, "SSI_PATFAM", "SSI_POTENCIALES_FAMILIAS", "N:1", "PF_ID_FAMILIA", "PF_ID_FAMILIA")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_PATFAM", "N:1", "PA_ID_PATFAM", "PA_ID_PATFAM")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_OBJETIVOS_ESPECIFICOS", "N:1", "OE_ID_OBJETIVO", "OE_ID_OBJETIVO")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_MODULOS", "N:1", "MO_ID_MODULO", "MO_ID_MODULO")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_UNIDADES", "N:1", "UN_ID_UNIDAD", "UN_ID_UNIDAD")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_TEMAS", "N:1", "TE_ID_TEMA", "TE_ID_TEMA")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_UNIDAD_SESIONES", "N:1", "SE_ID_SESION", "SE_ID_SESION")
add_relationship(er_diagram, "SSI_DET_PATFAM", "SSI_TALLERES", "N:1", "TA_ID_TALLER", "TA_ID_TALLER")
add_relationship(er_diagram, "SSI_EJECUCION_SESIONES", "SSI_DET_PATFAM", "N:1", "DP_ID_DET_PATFAM", "DP_ID_DET_PATFAM")
add_relationship(er_diagram, "SSI_EJECUCION_SESIONES", "SSI_UNIDAD_SESIONES", "N:1", "SE_ID_SESION", "SE_ID_SESION")
add_relationship(er_diagram, "SSI_EJEC_SESION_INTEGRANTES", "SSI_EJECUCION_SESIONES", "N:1", "ES_ID_EJECUCION", "ES_ID_EJECUCION")
add_relationship(er_diagram, "SSI_EJEC_SESION_INTEGRANTES", "SSI_FAMILIA_INTEGRANTES", "N:1", "FI_ID_INTEGRANTE", "FI_ID_INTEGRANTE")
add_relationship(er_diagram, "SSI_PROG_TALLERES", "SSI_TALLERES", "N:1", "TA_ID_TALLER", "TA_ID_TALLER")
add_relationship(er_diagram, "SSI_PROG_TALLER_FAMILIAS", "SSI_PROG_TALLERES", "N:1", "PT_ID_PROG_TALLER", "PT_ID_PROG_TALLER")
add_relationship(er_diagram, "SSI_PROG_TALLER_FAMILIAS", "SSI_DET_PATFAM", "N:1", "DP_ID_DET_PATFAM", "DP_ID_DET_PATFAM")
add_relationship(er_diagram, "SSI_PROG_TALLER_FAMILIAS", "SSI_POTENCIALES_FAMILIAS", "N:1", "PF_ID_FAMILIA", "PF_ID_FAMILIA")
add_relationship(er_diagram, "SSI_ANEXO_FASES", "SSI_SERVICIOS_INABIF", "N:1", "SF_ID_SERVICIO", "SI_ID_SERVICIO")
add_relationship(er_diagram, "SSI_ACTAS", "SSI_ALIADOS", "N:1", "AL_ID_ALIADO", "AL_ID_ALIADO")
add_relationship(er_diagram, "SSI_CODIGOS_FAMILIAS", "SSI_SERVICIOS_INABIF", "N:1", "SI_ID_SERVICIO", "SI_ID_SERVICIO")
add_relationship(er_diagram, "SSI_CODIGOS_FAMILIAS", "SSI_POTENCIALES_FAMILIAS", "N:1", "PF_ID_FAMILIA", "PF_ID_FAMILIA")
add_relationship(er_diagram, "SSI_CODIGOS_FAMILIAS", "SSI_FAMILIA_INTEGRANTES", "N:1", "FI_ID_INTEGRANTE", "FI_ID_INTEGRANTE")

# Renderizar y guardar el diagrama
er_diagram.render('ssi_er_diagram_horizontal', view=True, cleanup=True)
